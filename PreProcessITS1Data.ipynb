# %%
import glob
import hashlib
import pandas as pd
from Bio import SeqIO

# %% [markdown]
# ### Extract qz files for dada2

# %%
# !mkdir DB
# !mkdir temp
# !mkdir -p dada/ITS1 

for i in glob.glob('raw_data/ITS1/*.fastq.gz'):
    outf = 'temp/%s' % i.split('/')[-1].replace('.gz','')
    # !zcat $i > $outf
# Out:
# mkdir: cannot create directory ‘DB’: File exists
# mkdir: cannot create directory ‘temp’: File exists

# %% [markdown]
# ### Write dada2 script

# %%
# %%file ITS1_DADA2.R
#
# library(Matrix);
# library(dada2);
#
# path <- "~/GeoDiversity/temp" # CHANGE ME to the directory containing the fastq files after unzipping.
# # Forward and reverse fastq filenames have format: SAMPLENAME_R1_001.fastq and SAMPLENAME_R2_001.fastq
# fnFs <- sort(list.files(path, pattern="_R1_001.fastq", full.names = TRUE))
# fnRs <- sort(list.files(path, pattern="_R2_001.fastq", full.names = TRUE))
# # Extract sample names, assuming filenames have format: SAMPLENAME_XXX.fastq
# sample.names <- sapply(strsplit(basename(fnFs), "_"), `[`, 1)
# # Place filtered files in filtered/ subdirectory
# path1 = "~/GeoDiversity/cut_reads"
# filtFs <- file.path(path1, "ITS1", paste0(sample.names, "_F_filt.fastq.gz"))
# filtRs <- file.path(path1, "ITS1", paste0(sample.names, "_R_filt.fastq.gz"))
# out <- filterAndTrim(fnFs, filtFs, fnRs, filtRs, truncLen=c(125,125),
#               maxN=0, maxEE=c(4,5), truncQ=10, rm.phix=TRUE, trimLeft=0,
#               compress=TRUE, multithread=TRUE)
# # learn F errors
# errF <- learnErrors(filtFs, multithread=TRUE)
# print('learn R errors')
# errR <- learnErrors(filtRs, multithread=TRUE)
#
# # derep F
# derepFs <- derepFastq(filtFs, verbose=TRUE)
# # derep R
# derepRs <- derepFastq(filtRs, verbose=TRUE)
# # Name the derep-class objects by the sample names
# names(derepFs) <- sample.names
# names(derepRs) <- sample.names
#
# # dada F
# dadaFs <- dada(derepFs, err=errF, multithread=TRUE)
# # dada R
# dadaRs <- dada(derepRs, err=errR, multithread=TRUE)
#
# # merging
# mergers <- mergePairs(dadaFs, derepFs, dadaRs, derepRs, verbose=TRUE, justConcatenate=TRUE)
# seqtab <- makeSequenceTable(mergers)
#
# # chimera removal
# seqtab.nochim <- removeBimeraDenovo(seqtab, method="consensus", multithread=TRUE, verbose=TRUE)
#
# # assign taxonomy
# taxa <- assignTaxonomy(seqtab, "~/GeoDiversity/DB/sh_general_release_dynamic_02.02.2019.fasta")
#
# # write outputs
# uniquesToFasta(seqtab, 'dada/ITS1/rep-seqs.fasta')
# write.csv(seqtab, file = "dada/ITS1/table.csv")
# write.csv(taxa, file = "dada/ITS1/taxa.csv")
# Out:
# Overwriting ITS1_DADA2.R

# %% [markdown]
# ### Run dada2

# %%
# !Rscript ITS1_DADA2.R
# Out:
# Loading required package: Rcpp
# Creating output directory: /home/amir/GeoDiversity/cut_reads/ITS1
# 101497500 total bases in 811980 reads from 62 samples will be used for learning the error rates.
# [1] "learn R errors"
# 101497500 total bases in 811980 reads from 62 samples will be used for learning the error rates.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3000_F_filt.fastq.gz
# Encountered 5657 unique sequences from 20211 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3001_F_filt.fastq.gz
# Encountered 3698 unique sequences from 15477 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3002_F_filt.fastq.gz
# Encountered 3981 unique sequences from 17678 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3003_F_filt.fastq.gz
# Encountered 1817 unique sequences from 8343 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3004_F_filt.fastq.gz
# Encountered 3417 unique sequences from 12793 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3005_F_filt.fastq.gz
# Encountered 2775 unique sequences from 13776 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3006_F_filt.fastq.gz
# Encountered 1296 unique sequences from 5036 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3007_F_filt.fastq.gz
# Encountered 3213 unique sequences from 16296 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3008_F_filt.fastq.gz
# Encountered 5133 unique sequences from 17768 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3009_F_filt.fastq.gz
# Encountered 3984 unique sequences from 16561 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3010_F_filt.fastq.gz
# Encountered 4277 unique sequences from 16722 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3011_F_filt.fastq.gz
# Encountered 2620 unique sequences from 9639 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3012_F_filt.fastq.gz
# Encountered 3754 unique sequences from 15861 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3013_F_filt.fastq.gz
# Encountered 1674 unique sequences from 7320 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3014_F_filt.fastq.gz
# Encountered 3214 unique sequences from 14952 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3015_F_filt.fastq.gz
# Encountered 3834 unique sequences from 15158 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3016_F_filt.fastq.gz
# Encountered 1885 unique sequences from 5759 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3017_F_filt.fastq.gz
# Encountered 3058 unique sequences from 11935 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3018_F_filt.fastq.gz
# Encountered 3733 unique sequences from 12424 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3019_F_filt.fastq.gz
# Encountered 2559 unique sequences from 9286 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3020_F_filt.fastq.gz
# Encountered 3330 unique sequences from 13108 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3021_F_filt.fastq.gz
# Encountered 3103 unique sequences from 10514 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3022_F_filt.fastq.gz
# Encountered 3219 unique sequences from 12929 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3023_F_filt.fastq.gz
# Encountered 3979 unique sequences from 15853 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3024_F_filt.fastq.gz
# Encountered 344 unique sequences from 807 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3025_F_filt.fastq.gz
# Encountered 3714 unique sequences from 15244 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3026_F_filt.fastq.gz
# Encountered 3071 unique sequences from 11936 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3027_F_filt.fastq.gz
# Encountered 2483 unique sequences from 11276 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3028_F_filt.fastq.gz
# Encountered 3392 unique sequences from 16128 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3029_F_filt.fastq.gz
# Encountered 3655 unique sequences from 15992 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3030_F_filt.fastq.gz
# Encountered 1 unique sequences from 1 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3031_F_filt.fastq.gz
# Encountered 5092 unique sequences from 18476 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3032_F_filt.fastq.gz
# Encountered 2432 unique sequences from 9439 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3033_F_filt.fastq.gz
# Encountered 3789 unique sequences from 12731 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3034_F_filt.fastq.gz
# Encountered 3169 unique sequences from 12757 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3035_F_filt.fastq.gz
# Encountered 1305 unique sequences from 3422 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3036_F_filt.fastq.gz
# Encountered 2813 unique sequences from 9084 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3037_F_filt.fastq.gz
# Encountered 3127 unique sequences from 11727 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3038_F_filt.fastq.gz
# Encountered 3502 unique sequences from 16714 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3039_F_filt.fastq.gz
# Encountered 5103 unique sequences from 18978 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3040_F_filt.fastq.gz
# Encountered 2456 unique sequences from 10798 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3041_F_filt.fastq.gz
# Encountered 3440 unique sequences from 11674 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3042_F_filt.fastq.gz
# Encountered 5020 unique sequences from 15936 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3043_F_filt.fastq.gz
# Encountered 3039 unique sequences from 21043 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3044_F_filt.fastq.gz
# Encountered 3041 unique sequences from 10830 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3045_F_filt.fastq.gz
# Encountered 2718 unique sequences from 9023 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3046_F_filt.fastq.gz
# Encountered 4478 unique sequences from 14647 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3047_F_filt.fastq.gz
# Encountered 5648 unique sequences from 20329 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3048_F_filt.fastq.gz
# Encountered 2705 unique sequences from 14795 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3049_F_filt.fastq.gz
# Encountered 3211 unique sequences from 12573 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3050_F_filt.fastq.gz
# Encountered 2033 unique sequences from 14622 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3051_F_filt.fastq.gz
# Encountered 2043 unique sequences from 7052 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3052_F_filt.fastq.gz
# Encountered 4285 unique sequences from 14043 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3053_F_filt.fastq.gz
# Encountered 3463 unique sequences from 12157 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3054_F_filt.fastq.gz
# Encountered 3641 unique sequences from 12957 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3055_F_filt.fastq.gz
# Encountered 4869 unique sequences from 18857 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3056_F_filt.fastq.gz
# Encountered 4222 unique sequences from 16002 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3057_F_filt.fastq.gz
# Encountered 4880 unique sequences from 21108 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3058_F_filt.fastq.gz
# Encountered 4608 unique sequences from 18416 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3059_F_filt.fastq.gz
# Encountered 2575 unique sequences from 10824 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3060_F_filt.fastq.gz
# Encountered 2118 unique sequences from 7915 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3061_F_filt.fastq.gz
# Encountered 3432 unique sequences from 16268 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3062_F_filt.fastq.gz
# Encountered 170 unique sequences from 388 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3063_F_filt.fastq.gz
# Encountered 4419 unique sequences from 24685 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3064_F_filt.fastq.gz
# Encountered 4146 unique sequences from 17715 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3065_F_filt.fastq.gz
# Encountered 3521 unique sequences from 13058 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3066_F_filt.fastq.gz
# Encountered 4762 unique sequences from 18292 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3067_F_filt.fastq.gz
# Encountered 3796 unique sequences from 14336 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3070_F_filt.fastq.gz
# Encountered 3682 unique sequences from 10941 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3071_F_filt.fastq.gz
# Encountered 3910 unique sequences from 16315 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3072_F_filt.fastq.gz
# Encountered 3552 unique sequences from 17844 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3073_F_filt.fastq.gz
# Encountered 866 unique sequences from 2878 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3074_F_filt.fastq.gz
# Encountered 473 unique sequences from 1253 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3075_F_filt.fastq.gz
# Encountered 554 unique sequences from 1962 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3000_R_filt.fastq.gz
# Encountered 8423 unique sequences from 20211 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3001_R_filt.fastq.gz
# Encountered 5655 unique sequences from 15477 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3002_R_filt.fastq.gz
# Encountered 6484 unique sequences from 17678 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3003_R_filt.fastq.gz
# Encountered 2588 unique sequences from 8343 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3004_R_filt.fastq.gz
# Encountered 5185 unique sequences from 12793 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3005_R_filt.fastq.gz
# Encountered 4376 unique sequences from 13776 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3006_R_filt.fastq.gz
# Encountered 2260 unique sequences from 5036 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3007_R_filt.fastq.gz
# Encountered 4795 unique sequences from 16296 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3008_R_filt.fastq.gz
# Encountered 7777 unique sequences from 17768 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3009_R_filt.fastq.gz
# Encountered 6543 unique sequences from 16561 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3010_R_filt.fastq.gz
# Encountered 6287 unique sequences from 16722 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3011_R_filt.fastq.gz
# Encountered 4077 unique sequences from 9639 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3012_R_filt.fastq.gz
# Encountered 5776 unique sequences from 15861 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3013_R_filt.fastq.gz
# Encountered 2407 unique sequences from 7320 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3014_R_filt.fastq.gz
# Encountered 5274 unique sequences from 14952 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3015_R_filt.fastq.gz
# Encountered 6090 unique sequences from 15158 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3016_R_filt.fastq.gz
# Encountered 3010 unique sequences from 5759 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3017_R_filt.fastq.gz
# Encountered 4672 unique sequences from 11935 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3018_R_filt.fastq.gz
# Encountered 5301 unique sequences from 12424 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3019_R_filt.fastq.gz
# Encountered 3878 unique sequences from 9286 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3020_R_filt.fastq.gz
# Encountered 5221 unique sequences from 13108 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3021_R_filt.fastq.gz
# Encountered 4536 unique sequences from 10514 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3022_R_filt.fastq.gz
# Encountered 4886 unique sequences from 12929 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3023_R_filt.fastq.gz
# Encountered 6504 unique sequences from 15853 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3024_R_filt.fastq.gz
# Encountered 460 unique sequences from 807 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3025_R_filt.fastq.gz
# Encountered 5481 unique sequences from 15244 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3026_R_filt.fastq.gz
# Encountered 4612 unique sequences from 11936 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3027_R_filt.fastq.gz
# Encountered 3769 unique sequences from 11276 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3028_R_filt.fastq.gz
# Encountered 6121 unique sequences from 16128 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3029_R_filt.fastq.gz
# Encountered 5754 unique sequences from 15992 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3030_R_filt.fastq.gz
# Encountered 1 unique sequences from 1 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3031_R_filt.fastq.gz
# Encountered 7230 unique sequences from 18476 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3032_R_filt.fastq.gz
# Encountered 3686 unique sequences from 9439 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3033_R_filt.fastq.gz
# Encountered 5778 unique sequences from 12731 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3034_R_filt.fastq.gz
# Encountered 4804 unique sequences from 12757 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3035_R_filt.fastq.gz
# Encountered 1879 unique sequences from 3422 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3036_R_filt.fastq.gz
# Encountered 3726 unique sequences from 9084 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3037_R_filt.fastq.gz
# Encountered 4531 unique sequences from 11727 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3038_R_filt.fastq.gz
# Encountered 5895 unique sequences from 16714 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3039_R_filt.fastq.gz
# Encountered 7112 unique sequences from 18978 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3040_R_filt.fastq.gz
# Encountered 3575 unique sequences from 10798 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3041_R_filt.fastq.gz
# Encountered 5041 unique sequences from 11674 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3042_R_filt.fastq.gz
# Encountered 7653 unique sequences from 15936 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3043_R_filt.fastq.gz
# Encountered 4832 unique sequences from 21043 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3044_R_filt.fastq.gz
# Encountered 4461 unique sequences from 10830 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3045_R_filt.fastq.gz
# Encountered 3848 unique sequences from 9023 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3046_R_filt.fastq.gz
# Encountered 6555 unique sequences from 14647 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3047_R_filt.fastq.gz
# Encountered 8275 unique sequences from 20329 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3048_R_filt.fastq.gz
# Encountered 4426 unique sequences from 14795 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3049_R_filt.fastq.gz
# Encountered 4651 unique sequences from 12573 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3050_R_filt.fastq.gz
# Encountered 3525 unique sequences from 14622 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3051_R_filt.fastq.gz
# Encountered 3151 unique sequences from 7052 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3052_R_filt.fastq.gz
# Encountered 6428 unique sequences from 14043 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3053_R_filt.fastq.gz
# Encountered 5054 unique sequences from 12157 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3054_R_filt.fastq.gz
# Encountered 5596 unique sequences from 12957 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3055_R_filt.fastq.gz
# Encountered 7631 unique sequences from 18857 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3056_R_filt.fastq.gz
# Encountered 6466 unique sequences from 16002 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3057_R_filt.fastq.gz
# Encountered 7878 unique sequences from 21108 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3058_R_filt.fastq.gz
# Encountered 7681 unique sequences from 18416 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3059_R_filt.fastq.gz
# Encountered 3512 unique sequences from 10824 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3060_R_filt.fastq.gz
# Encountered 3013 unique sequences from 7915 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3061_R_filt.fastq.gz
# Encountered 5119 unique sequences from 16268 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3062_R_filt.fastq.gz
# Encountered 241 unique sequences from 388 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3063_R_filt.fastq.gz
# Encountered 6363 unique sequences from 24685 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3064_R_filt.fastq.gz
# Encountered 6808 unique sequences from 17715 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3065_R_filt.fastq.gz
# Encountered 5073 unique sequences from 13058 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3066_R_filt.fastq.gz
# Encountered 6794 unique sequences from 18292 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3067_R_filt.fastq.gz
# Encountered 5594 unique sequences from 14336 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3070_R_filt.fastq.gz
# Encountered 5462 unique sequences from 10941 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3071_R_filt.fastq.gz
# Encountered 5656 unique sequences from 16315 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3072_R_filt.fastq.gz
# Encountered 5749 unique sequences from 17844 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3073_R_filt.fastq.gz
# Encountered 1238 unique sequences from 2878 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3074_R_filt.fastq.gz
# Encountered 751 unique sequences from 1253 total sequences read.
# Dereplicating sequence entries in Fastq file: ~/GeoDiversity/cut_reads/ITS1/ITS-AS3075_R_filt.fastq.gz
# Encountered 835 unique sequences from 1962 total sequences read.
# Sample 1 - 20211 reads in 5657 unique sequences.
# Sample 2 - 15477 reads in 3698 unique sequences.
# Sample 3 - 17678 reads in 3981 unique sequences.
# Sample 4 - 8343 reads in 1817 unique sequences.
# Sample 5 - 12793 reads in 3417 unique sequences.
# Sample 6 - 13776 reads in 2775 unique sequences.
# Sample 7 - 5036 reads in 1296 unique sequences.
# Sample 8 - 16296 reads in 3213 unique sequences.
# Sample 9 - 17768 reads in 5133 unique sequences.
# Sample 10 - 16561 reads in 3984 unique sequences.
# Sample 11 - 16722 reads in 4277 unique sequences.
# Sample 12 - 9639 reads in 2620 unique sequences.
# Sample 13 - 15861 reads in 3754 unique sequences.
# Sample 14 - 7320 reads in 1674 unique sequences.
# Sample 15 - 14952 reads in 3214 unique sequences.
# Sample 16 - 15158 reads in 3834 unique sequences.
# Sample 17 - 5759 reads in 1885 unique sequences.
# Sample 18 - 11935 reads in 3058 unique sequences.
# Sample 19 - 12424 reads in 3733 unique sequences.
# Sample 20 - 9286 reads in 2559 unique sequences.
# Sample 21 - 13108 reads in 3330 unique sequences.
# Sample 22 - 10514 reads in 3103 unique sequences.
# Sample 23 - 12929 reads in 3219 unique sequences.
# Sample 24 - 15853 reads in 3979 unique sequences.
# Sample 25 - 807 reads in 344 unique sequences.
# Sample 26 - 15244 reads in 3714 unique sequences.
# Sample 27 - 11936 reads in 3071 unique sequences.
# Sample 28 - 11276 reads in 2483 unique sequences.
# Sample 29 - 16128 reads in 3392 unique sequences.
# Sample 30 - 15992 reads in 3655 unique sequences.
# Sample 31 - 1 reads in 1 unique sequences.
# Sample 32 - 18476 reads in 5092 unique sequences.
# Sample 33 - 9439 reads in 2432 unique sequences.
# Sample 34 - 12731 reads in 3789 unique sequences.
# Sample 35 - 12757 reads in 3169 unique sequences.
# Sample 36 - 3422 reads in 1305 unique sequences.
# Sample 37 - 9084 reads in 2813 unique sequences.
# Sample 38 - 11727 reads in 3127 unique sequences.
# Sample 39 - 16714 reads in 3502 unique sequences.
# Sample 40 - 18978 reads in 5103 unique sequences.
# Sample 41 - 10798 reads in 2456 unique sequences.
# Sample 42 - 11674 reads in 3440 unique sequences.
# Sample 43 - 15936 reads in 5020 unique sequences.
# Sample 44 - 21043 reads in 3039 unique sequences.
# Sample 45 - 10830 reads in 3041 unique sequences.
# Sample 46 - 9023 reads in 2718 unique sequences.
# Sample 47 - 14647 reads in 4478 unique sequences.
# Sample 48 - 20329 reads in 5648 unique sequences.
# Sample 49 - 14795 reads in 2705 unique sequences.
# Sample 50 - 12573 reads in 3211 unique sequences.
# Sample 51 - 14622 reads in 2033 unique sequences.
# Sample 52 - 7052 reads in 2043 unique sequences.
# Sample 53 - 14043 reads in 4285 unique sequences.
# Sample 54 - 12157 reads in 3463 unique sequences.
# Sample 55 - 12957 reads in 3641 unique sequences.
# Sample 56 - 18857 reads in 4869 unique sequences.
# Sample 57 - 16002 reads in 4222 unique sequences.
# Sample 58 - 21108 reads in 4880 unique sequences.
# Sample 59 - 18416 reads in 4608 unique sequences.
# Sample 60 - 10824 reads in 2575 unique sequences.
# Sample 61 - 7915 reads in 2118 unique sequences.
# Sample 62 - 16268 reads in 3432 unique sequences.
# Sample 63 - 388 reads in 170 unique sequences.
# Sample 64 - 24685 reads in 4419 unique sequences.
# Sample 65 - 17715 reads in 4146 unique sequences.
# Sample 66 - 13058 reads in 3521 unique sequences.
# Sample 67 - 18292 reads in 4762 unique sequences.
# Sample 68 - 14336 reads in 3796 unique sequences.
# Sample 69 - 10941 reads in 3682 unique sequences.
# Sample 70 - 16315 reads in 3910 unique sequences.
# Sample 71 - 17844 reads in 3552 unique sequences.
# Sample 72 - 2878 reads in 866 unique sequences.
# Sample 73 - 1253 reads in 473 unique sequences.
# Sample 74 - 1962 reads in 554 unique sequences.
# Sample 1 - 20211 reads in 8423 unique sequences.
# Sample 2 - 15477 reads in 5655 unique sequences.
# Sample 3 - 17678 reads in 6484 unique sequences.
# Sample 4 - 8343 reads in 2588 unique sequences.
# Sample 5 - 12793 reads in 5185 unique sequences.
# Sample 6 - 13776 reads in 4376 unique sequences.
# Sample 7 - 5036 reads in 2260 unique sequences.
# Sample 8 - 16296 reads in 4795 unique sequences.
# Sample 9 - 17768 reads in 7777 unique sequences.
# Sample 10 - 16561 reads in 6543 unique sequences.
# Sample 11 - 16722 reads in 6287 unique sequences.
# Sample 12 - 9639 reads in 4077 unique sequences.
# Sample 13 - 15861 reads in 5776 unique sequences.
# Sample 14 - 7320 reads in 2407 unique sequences.
# Sample 15 - 14952 reads in 5274 unique sequences.
# Sample 16 - 15158 reads in 6090 unique sequences.
# Sample 17 - 5759 reads in 3010 unique sequences.
# Sample 18 - 11935 reads in 4672 unique sequences.
# Sample 19 - 12424 reads in 5301 unique sequences.
# Sample 20 - 9286 reads in 3878 unique sequences.
# Sample 21 - 13108 reads in 5221 unique sequences.
# Sample 22 - 10514 reads in 4536 unique sequences.
# Sample 23 - 12929 reads in 4886 unique sequences.
# Sample 24 - 15853 reads in 6504 unique sequences.
# Sample 25 - 807 reads in 460 unique sequences.
# Sample 26 - 15244 reads in 5481 unique sequences.
# Sample 27 - 11936 reads in 4612 unique sequences.
# Sample 28 - 11276 reads in 3769 unique sequences.
# Sample 29 - 16128 reads in 6121 unique sequences.
# Sample 30 - 15992 reads in 5754 unique sequences.
# Sample 31 - 1 reads in 1 unique sequences.
# Sample 32 - 18476 reads in 7230 unique sequences.
# Sample 33 - 9439 reads in 3686 unique sequences.
# Sample 34 - 12731 reads in 5778 unique sequences.
# Sample 35 - 12757 reads in 4804 unique sequences.
# Sample 36 - 3422 reads in 1879 unique sequences.
# Sample 37 - 9084 reads in 3726 unique sequences.
# Sample 38 - 11727 reads in 4531 unique sequences.
# Sample 39 - 16714 reads in 5895 unique sequences.
# Sample 40 - 18978 reads in 7112 unique sequences.
# Sample 41 - 10798 reads in 3575 unique sequences.
# Sample 42 - 11674 reads in 5041 unique sequences.
# Sample 43 - 15936 reads in 7653 unique sequences.
# Sample 44 - 21043 reads in 4832 unique sequences.
# Sample 45 - 10830 reads in 4461 unique sequences.
# Sample 46 - 9023 reads in 3848 unique sequences.
# Sample 47 - 14647 reads in 6555 unique sequences.
# Sample 48 - 20329 reads in 8275 unique sequences.
# Sample 49 - 14795 reads in 4426 unique sequences.
# Sample 50 - 12573 reads in 4651 unique sequences.
# Sample 51 - 14622 reads in 3525 unique sequences.
# Sample 52 - 7052 reads in 3151 unique sequences.
# Sample 53 - 14043 reads in 6428 unique sequences.
# Sample 54 - 12157 reads in 5054 unique sequences.
# Sample 55 - 12957 reads in 5596 unique sequences.
# Sample 56 - 18857 reads in 7631 unique sequences.
# Sample 57 - 16002 reads in 6466 unique sequences.
# Sample 58 - 21108 reads in 7878 unique sequences.
# Sample 59 - 18416 reads in 7681 unique sequences.
# Sample 60 - 10824 reads in 3512 unique sequences.
# Sample 61 - 7915 reads in 3013 unique sequences.
# Sample 62 - 16268 reads in 5119 unique sequences.
# Sample 63 - 388 reads in 241 unique sequences.
# Sample 64 - 24685 reads in 6363 unique sequences.
# Sample 65 - 17715 reads in 6808 unique sequences.
# Sample 66 - 13058 reads in 5073 unique sequences.
# Sample 67 - 18292 reads in 6794 unique sequences.
# Sample 68 - 14336 reads in 5594 unique sequences.
# Sample 69 - 10941 reads in 5462 unique sequences.
# Sample 70 - 16315 reads in 5656 unique sequences.
# Sample 71 - 17844 reads in 5749 unique sequences.
# Sample 72 - 2878 reads in 1238 unique sequences.
# Sample 73 - 1253 reads in 751 unique sequences.
# Sample 74 - 1962 reads in 835 unique sequences.
# 19088 paired-reads (in 549 unique pairings) successfully merged out of 19088 (in 549 pairings) input.
# 14705 paired-reads (in 318 unique pairings) successfully merged out of 14705 (in 318 pairings) input.
# 16645 paired-reads (in 379 unique pairings) successfully merged out of 16645 (in 379 pairings) input.
# 7957 paired-reads (in 168 unique pairings) successfully merged out of 7957 (in 168 pairings) input.
# 11915 paired-reads (in 271 unique pairings) successfully merged out of 11915 (in 271 pairings) input.
# 13135 paired-reads (in 202 unique pairings) successfully merged out of 13135 (in 202 pairings) input.
# 4741 paired-reads (in 107 unique pairings) successfully merged out of 4741 (in 107 pairings) input.
# 15569 paired-reads (in 189 unique pairings) successfully merged out of 15569 (in 189 pairings) input.
# 16579 paired-reads (in 406 unique pairings) successfully merged out of 16579 (in 406 pairings) input.
# 15652 paired-reads (in 366 unique pairings) successfully merged out of 15652 (in 366 pairings) input.
# 15804 paired-reads (in 450 unique pairings) successfully merged out of 15804 (in 450 pairings) input.
# 9040 paired-reads (in 239 unique pairings) successfully merged out of 9040 (in 239 pairings) input.
# 14942 paired-reads (in 342 unique pairings) successfully merged out of 14942 (in 342 pairings) input.
# 6929 paired-reads (in 139 unique pairings) successfully merged out of 6929 (in 139 pairings) input.
# 14173 paired-reads (in 292 unique pairings) successfully merged out of 14173 (in 292 pairings) input.
# 14393 paired-reads (in 343 unique pairings) successfully merged out of 14393 (in 343 pairings) input.
# 5273 paired-reads (in 165 unique pairings) successfully merged out of 5273 (in 165 pairings) input.
# 11192 paired-reads (in 226 unique pairings) successfully merged out of 11192 (in 226 pairings) input.
# 11645 paired-reads (in 318 unique pairings) successfully merged out of 11645 (in 318 pairings) input.
# 8666 paired-reads (in 262 unique pairings) successfully merged out of 8666 (in 262 pairings) input.
# 12217 paired-reads (in 393 unique pairings) successfully merged out of 12217 (in 393 pairings) input.
# 9837 paired-reads (in 317 unique pairings) successfully merged out of 9837 (in 317 pairings) input.
# 12242 paired-reads (in 242 unique pairings) successfully merged out of 12242 (in 242 pairings) input.
# 15116 paired-reads (in 229 unique pairings) successfully merged out of 15116 (in 229 pairings) input.
# 665 paired-reads (in 30 unique pairings) successfully merged out of 665 (in 30 pairings) input.
# 14355 paired-reads (in 336 unique pairings) successfully merged out of 14355 (in 336 pairings) input.
# 11088 paired-reads (in 341 unique pairings) successfully merged out of 11088 (in 341 pairings) input.
# 10742 paired-reads (in 271 unique pairings) successfully merged out of 10742 (in 271 pairings) input.
# 15207 paired-reads (in 511 unique pairings) successfully merged out of 15207 (in 511 pairings) input.
# 15171 paired-reads (in 302 unique pairings) successfully merged out of 15171 (in 302 pairings) input.
# 1 paired-reads (in 1 unique pairings) successfully merged out of 1 (in 1 pairings) input.
# 17363 paired-reads (in 512 unique pairings) successfully merged out of 17363 (in 512 pairings) input.
# 8859 paired-reads (in 183 unique pairings) successfully merged out of 8859 (in 183 pairings) input.
# 11579 paired-reads (in 361 unique pairings) successfully merged out of 11579 (in 361 pairings) input.
# 12080 paired-reads (in 265 unique pairings) successfully merged out of 12080 (in 265 pairings) input.
# 3061 paired-reads (in 115 unique pairings) successfully merged out of 3061 (in 115 pairings) input.
# 8402 paired-reads (in 321 unique pairings) successfully merged out of 8402 (in 321 pairings) input.
# 10995 paired-reads (in 253 unique pairings) successfully merged out of 10995 (in 253 pairings) input.
# 15855 paired-reads (in 307 unique pairings) successfully merged out of 15855 (in 307 pairings) input.
# 17958 paired-reads (in 579 unique pairings) successfully merged out of 17958 (in 579 pairings) input.
# 10027 paired-reads (in 262 unique pairings) successfully merged out of 10027 (in 262 pairings) input.
# 10745 paired-reads (in 403 unique pairings) successfully merged out of 10745 (in 403 pairings) input.
# 14527 paired-reads (in 397 unique pairings) successfully merged out of 14527 (in 397 pairings) input.
# 20342 paired-reads (in 183 unique pairings) successfully merged out of 20342 (in 183 pairings) input.
# 10043 paired-reads (in 240 unique pairings) successfully merged out of 10043 (in 240 pairings) input.
# 8481 paired-reads (in 208 unique pairings) successfully merged out of 8481 (in 208 pairings) input.
# 13396 paired-reads (in 442 unique pairings) successfully merged out of 13396 (in 442 pairings) input.
# 19238 paired-reads (in 369 unique pairings) successfully merged out of 19238 (in 369 pairings) input.
# 14324 paired-reads (in 150 unique pairings) successfully merged out of 14324 (in 150 pairings) input.
# 11802 paired-reads (in 344 unique pairings) successfully merged out of 11802 (in 344 pairings) input.
# 14190 paired-reads (in 112 unique pairings) successfully merged out of 14190 (in 112 pairings) input.
# 6463 paired-reads (in 225 unique pairings) successfully merged out of 6463 (in 225 pairings) input.
# 12878 paired-reads (in 403 unique pairings) successfully merged out of 12878 (in 403 pairings) input.
# 11094 paired-reads (in 336 unique pairings) successfully merged out of 11094 (in 336 pairings) input.
# 12073 paired-reads (in 384 unique pairings) successfully merged out of 12073 (in 384 pairings) input.
# 17701 paired-reads (in 511 unique pairings) successfully merged out of 17701 (in 511 pairings) input.
# 14918 paired-reads (in 439 unique pairings) successfully merged out of 14918 (in 439 pairings) input.
# 20025 paired-reads (in 544 unique pairings) successfully merged out of 20025 (in 544 pairings) input.
# 17370 paired-reads (in 471 unique pairings) successfully merged out of 17370 (in 471 pairings) input.
# 10318 paired-reads (in 319 unique pairings) successfully merged out of 10318 (in 319 pairings) input.
# 7322 paired-reads (in 259 unique pairings) successfully merged out of 7322 (in 259 pairings) input.
# 15586 paired-reads (in 313 unique pairings) successfully merged out of 15586 (in 313 pairings) input.
# 295 paired-reads (in 19 unique pairings) successfully merged out of 295 (in 19 pairings) input.
# 23945 paired-reads (in 486 unique pairings) successfully merged out of 23945 (in 486 pairings) input.
# 16771 paired-reads (in 417 unique pairings) successfully merged out of 16771 (in 417 pairings) input.
# 12107 paired-reads (in 302 unique pairings) successfully merged out of 12107 (in 302 pairings) input.
# 17224 paired-reads (in 463 unique pairings) successfully merged out of 17224 (in 463 pairings) input.
# 13401 paired-reads (in 480 unique pairings) successfully merged out of 13401 (in 480 pairings) input.
# 9962 paired-reads (in 359 unique pairings) successfully merged out of 9962 (in 359 pairings) input.
# 15473 paired-reads (in 373 unique pairings) successfully merged out of 15473 (in 373 pairings) input.
# 17104 paired-reads (in 257 unique pairings) successfully merged out of 17104 (in 257 pairings) input.
# 2571 paired-reads (in 66 unique pairings) successfully merged out of 2571 (in 66 pairings) input.
# 1007 paired-reads (in 33 unique pairings) successfully merged out of 1007 (in 33 pairings) input.
# 1740 paired-reads (in 63 unique pairings) successfully merged out of 1740 (in 63 pairings) input.
# Identified 6435 bimeras out of 13224 input sequences.
# UNITE fungal taxonomic reference detected.

# %% [markdown]
# ### Import to qiime2

# %%
# add md5 hashes to table
df = pd.read_csv('dada/ITS1/table.csv',index_col=0).transpose()
df.index = [hashlib.md5(i.encode()).hexdigest() for i in df.index]
df.index.name = '#Feature_id'
df.to_csv('temp1',sep='\t')

# convert table to biom
# !biom convert -i temp1 -o dada/ITS1/table.biom --table-type="OTU table" --to-hdf5
# !rm temp1

# convert biom table to qza
# !qiime tools import \
  --input-path dada/ITS1/table.biom \
  --type 'FeatureTable[Frequency]' \
  --input-format BIOMV210Format \
  --output-path dada/ITS1/table.qza

# add md5 hashes to sequence headers
repseqs = list(SeqIO.parse('dada/ITS1/rep-seqs.fasta','fasta'))
for r in repseqs:
    r.id = hashlib.md5(str(r.seq).encode()).hexdigest()
    r.description = ''
SeqIO.write(repseqs,'temp1','fasta')

# convert fasta to qza
# !qiime tools import \
  --input-path temp1 \
  --output-path dada/ITS1/rep-seqs.qza \
  --type 'FeatureData[Sequence]'

# !rm temp1

# add md5 hashes to taxonomy table
with open('temp.tsv','wt') as hndl:
    first = True
    for l in open('dada/ITS1/taxa.csv'):
        if l.startswith('""'):
            continue
        if first:
            first=False
        else:
            hndl.write('\n')
        parts = l.rstrip().replace('"','').split(',')
        hndl.write(hashlib.md5(str(parts.pop(0)).encode()).hexdigest())
        hndl.write('\t')
        hndl.write(';'.join(parts))
        
# convert taxonomy table to qza
# !qiime tools import \
   --type FeatureData[Taxonomy] \
   --input-path temp.tsv \
   --output-path dada/ITS1/taxonomy.qza \
   --input-format HeaderlessTSVTaxonomyFormat

# !rm temp.tsv
# !rm -r temp
# Out:
# Imported dada/ITS1/table.biom as BIOMV210Format to dada/ITS1/table.qza
# Imported temp1 as DNASequencesDirectoryFormat to dada/ITS1/rep-seqs.qza
# Imported temp.tsv as HeaderlessTSVTaxonomyFormat to dada/ITS1/taxonomy.qza

# %% [markdown]
# ### make tree

# %%
# !qiime phylogeny align-to-tree-mafft-fasttree \
  --i-sequences dada/ITS1/rep-seqs.qza \
  --o-alignment dada/ITS1/aligned-rep-seqs.qza \
  --o-masked-alignment dada/ITS1/masked-aligned-rep-seqs.qza \
  --o-tree dada/ITS1/unrooted-tree.qza \
  --o-rooted-tree dada/ITS1/rooted-tree.qza
# Out:
# Saved FeatureData[AlignedSequence] to: dada/ITS1/aligned-rep-seqs.qza
# Saved FeatureData[AlignedSequence] to: dada/ITS1/masked-aligned-rep-seqs.qza
# Saved Phylogeny[Unrooted] to: dada/ITS1/unrooted-tree.qza
# Saved Phylogeny[Rooted] to: dada/ITS1/rooted-tree.qza

# %% [markdown]
# ### ITS1 metadata

# %%
with open('ITS1_metadata.tsv','wt') as hndl:
    header = True
    for l in open('16SrRNA_metadata.tsv'):
        if header == True:
            hndl.write(l)
            header = False
            continue
        hndl.write('ITS-'+l)
